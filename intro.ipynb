# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras import Sequential, Input
from tensorflow.keras.layers import Dense

# %%
model = Sequential([Input(shape=[1]), Dense(units = 1)])
model.compile(optimizer='sgd', loss='mean_squared_error')

# %%
xs = np.array([-1.0, 0.0, 1.0, 2.0,  3.0, 4.0])
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0])

model.fit(xs, ys, verbose=0, epochs=500)

# %%
model.predict(np.array([1]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# array([[1.0044795]], dtype=float32)

# %%
model.weights
# Out:
# [<Variable path=sequential_1/dense_1/kernel, shape=(1, 1), dtype=float32, value=[[1.9978675]]>,
#  <Variable path=sequential_1/dense_1/bias, shape=(1,), dtype=float32, value=[-0.99338794]>]
