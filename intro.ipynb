# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras import Sequential, Input
from tensorflow.keras.layers import Dense

# %%
model = Sequential([Input(shape=[1]), Dense(units = 1)])
model.compile(optimizer='sgd', loss='mean_squared_error')
# Out:
# 2026-03-24 23:44:26.822763: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M5 Max
# 2026-03-24 23:44:26.822780: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 64.00 GB
# 2026-03-24 23:44:26.822786: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 25.92 GB
# 2026-03-24 23:44:26.822798: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2026-03-24 23:44:26.822807: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
xs = np.array([-1.0, 0.0, 1.0, 2.0,  3.0, 4.0])
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0])

model.fit(xs, ys, verbose=0, epochs=500)
# Out:
# 2026-03-24 23:44:26.923960: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.

# %%
model.predict(np.array([10]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# array([[18.978401]], dtype=float32)

# %%
model.weights
# Out:
# [<Variable path=sequential/dense/kernel, shape=(1, 1), dtype=float32, value=[[1.9968694]]>,
#  <Variable path=sequential/dense/bias, shape=(1,), dtype=float32, value=[-0.99029386]>]
