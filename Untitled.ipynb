# %%
"Hello world"
# Out:
# 'Hello world'

# %% [markdown]
# ## This is a header

# %% [markdown]
# ## Jupyterlab Tutorial

# %% [markdown]
# This is a *test*.
#
# Hello world!

# %%
print("Hello again!")
# Out:
# Hello again!

# %%
import sys

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
print('hello world')
# Out:
# hello world

# %%
import polars as pl

# Create a simple DataFrame
df_polars = pl.DataFrame({
    'column_a': [1, 2, 3],
    'column_b': ['x', 'y', 'z']
})

# Display the DataFrame (Polars DataFrames pretty-print automatically in Jupyter)
df_polars
# Out:
# shape: (3, 2)
# ┌──────────┬──────────┐
# │ column_a ┆ column_b │
# │ ---      ┆ ---      │
# │ i64      ┆ str      │
# ╞══════════╪══════════╡
# │ 1        ┆ x        │
# │ 2        ┆ y        │
# │ 3        ┆ z        │
# └──────────┴──────────┘

# %%
import pandas as pd

# %%
# Create a simple DataFrame
df_pandas = pd.DataFrame({
    'column_a': [1, 2, 3],
    'column_b': ['x', 'y', 'z']
})

# Display the DataFrame (Polars DataFrames pretty-print automatically in Jupyter)
df_pandas
# Out:
#    column_a column_b
# 0         1        x
# 1         2        y
# 2         3        z
