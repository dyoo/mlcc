# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# This is a **Markdown** cell.

# %%
print(2**3)
# Out:
# 8

# %% [markdown]
# # Section 1

# %% [markdown]
# This is another test

# %% [markdown]
# # Section 2

# %%
def f(x):
    return x * x

# %%
f(16)
# Out:
# 256

# %%
import pandas as pd

data = {
    'Product_ID': ['1', '2', '3'],
    'Product_Name': ['Macbook', 'iPad', 'iPhone'],
    'Category': ['Electronics', 'Electronics', 'Electronics'],
    'Price': [599.99, 699.99, 1199.99],
    'Stock': [50, 49, 17],
}

# %%
df = pd.DataFrame(data)

# %%
import matplotlib.pyplot as plt

plt.scatter(df['Price'], df['Stock'])
plt.show()
